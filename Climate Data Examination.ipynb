# %% [markdown]
# # Average Surface Temperatures and Precipitations

# %% [markdown]
# In this project, I will examine the temperature and precipitation data of 21 countries bordering the Mediterranean using the World Bank's Climate Change Information Portal between 1950 and 2020.
#
#   (Spain, France, Monaco, Italy, Slovenia, Croatia, Bosnia and Herzegovina, Montenegro, Albania, Greece, Turkey, Syria, Lebanon, Israel, Egypt, Libya, Tunisia, Algeria, Morocco, Malta and Cyprus.)

# %% [markdown]
# Things I will do with the data set:
#
# - Computing the average surface temperature per month for each country, saving the results in a pandas data frame called MAST, and displaying the data using a line plot.
# - Computing the average precipitation per month for each country, saving the results in a pandas data frame called MAPR, and displaying the data using a line plot.
# - Computing the average surface temperature per year for each country, saving the results in a pandas data frame called YAST, and displaying the data using a line plot.
# - Computing the average precipitation per year for each country, saving the results in a pandas data frame called YAPR, and displaying the data using a line plot.

# %%
import pandas as pd
import json
import requests
import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# In the cell above, I imported "pandas" library to process the data, "requests" library to use the API link in the project, "datetime" library to be clear on dates and "json" library to process the data in json format.

# %%
def process_data(response, start_date="1950-01", end_date="2019-12"):
    data = response.json()
    df = pd.DataFrame(data["data"])

    selected_data = df.loc[start_date:end_date]
    selected_data.reset_index(inplace=True)


    selected_data = selected_data.rename(columns={'index': 'Date'})

    return selected_data

# %% [markdown]
# In the table below, you see the "Average Surface Temperature" value of each month between 1950 and 2020. In this way, I have now cleared the data. I can work on it.

# %%
response_temperature = requests.get("https://cckpapi.worldbank.org/cckp/v1/cru-x0.5_timeseries_tas_timeseries_monthly_1901-2022_mean_historical_cru_ts4.07_mean/GRC,ISR,TUR,ESP,REU,MCO,ITA,SVN,HRV,BIH,MNE,ALB,SYR,LBN,EGY,LBY,TUN,DZA,MAR,MLT,CYP?_format=json")
processed_data_temperature = process_data(response_temperature)

processed_data_temperature
# Out:
#         Date    ALB    BIH    CYP    DZA    EGY    ESP    GRC    HRV    ISR  \
# 0    1950-01   0.45  -2.93   7.76  12.00  12.37   5.11   2.32  -1.29  10.28
# 1    1950-02   4.24   1.74   8.77  15.02  13.63   7.52   5.99   3.44  10.93
# 2    1950-03   6.99   6.06  11.96  18.05  17.57   8.88   8.23   7.75  14.12
# 3    1950-04  11.72   9.49  17.35  21.78  23.71  10.46  13.74  10.72  19.25
# 4    1950-05  15.96  15.37  19.24  26.55  25.78  14.28  16.91  16.83  20.15
# ..       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 835  2019-08  23.85  21.91  28.04  33.07  30.71  23.44  25.27  23.18  27.02
# 836  2019-09  19.28  16.67  25.67  30.52  28.60  20.20  21.16  18.04  25.56
# 837  2019-10  15.00  12.66  22.97  24.91  26.12  15.56  16.98  14.10  23.44
# 838  2019-11  11.42   9.03  18.21  17.93  20.63   9.86  13.57   9.91  19.56
# 839  2019-12   6.07   3.31  13.01  14.38  15.46   8.43   7.75   4.85  14.67
#
#      ...    LBY    MAR   MCO    MLT    MNE    REU    SVN    SYR    TUN    TUR
# 0    ...  11.93   9.26   4.9  11.85  -2.95  22.17  -2.91   3.28  10.33  -4.70
# 1    ...  13.76  11.77   7.4  12.46   1.33  21.94   1.84   5.56  12.40  -1.51
# 2    ...  16.79  14.08   8.6  13.16   5.06  21.50   5.79  10.96  13.93   4.10
# 3    ...  22.54  15.88   9.0  15.29   9.00  20.56   7.99  18.29  17.15  12.51
# 4    ...  25.85  18.65  15.1  19.55  14.40  18.47  14.64  20.96  22.29  14.61
# ..   ...    ...    ...   ...    ...    ...    ...    ...    ...    ...    ...
# 835  ...  30.44  26.79  22.7  28.50  21.82  17.68  20.52  29.93  30.93  23.10
# 836  ...  28.40  23.90  19.6  25.76  16.69  18.37  15.61  26.54  27.32  19.23
# 837  ...  24.76  19.38  16.4  22.56  12.58  19.86  12.01  22.34  22.82  15.70
# 838  ...  18.84  14.00  10.3  17.79   9.05  21.06   6.75  14.34  15.98   8.96
# 839  ...  14.05  11.76   9.5  16.01   3.57  22.98   2.82   9.77  13.82   3.95
#
# [840 rows x 22 columns]

# %% [markdown]
# In the table below, you see the "Average Precipitation" value of each month between 1950 and 2020. In this way, I have now cleared the data. I can work on it

# %%
response_precipitation = requests.get("https://cckpapi.worldbank.org/cckp/v1/era5-x0.5_timeseries_pr_timeseries_monthly_1950-2020_mean_historical_era5_era5_mean/GRC,ISR,TUR,ESP,REU,MCO,ITA,SVN,HRV,BIH,MNE,ALB,SYR,LBN,EGY,LBY,TUN,DZA,MAR,MLT,CYP?_format=json")
processed_data_precipitation = process_data(response_precipitation)

processed_data_precipitation
# Out:
#         Date     ALB     BIH     CYP   DZA   EGY     ESP     GRC     HRV  \
# 0    1950-01   97.35   78.33   68.26  9.54  2.65   29.45   86.34   87.53
# 1    1950-02   87.45   87.53   30.95  3.24  1.60   57.43   59.23   78.08
# 2    1950-03   57.06   81.82   54.18  5.26  0.90   37.33   90.62   48.30
# 3    1950-04  108.63   85.88   32.61  5.48  0.94   33.08   67.39   98.04
# 4    1950-05   39.78   33.80   34.12  4.34  1.22   71.20   42.14   19.68
# ..       ...     ...     ...     ...   ...   ...     ...     ...     ...
# 835  2019-08   11.30   55.63    2.95  5.12  0.56   26.78    8.75   60.76
# 836  2019-09   66.99   73.94    9.94  7.75  0.06   51.34   24.28   95.01
# 837  2019-10   41.15   37.90   40.47  4.52  3.40   68.56   47.95   53.82
# 838  2019-11  270.47  187.44   29.88  7.82  0.70  100.81  156.73  217.78
# 839  2019-12  175.57  122.29  138.15  4.41  2.07  109.07  119.58  131.42
#
#        ISR  ...   LBY    MAR     MCO     MLT     MNE     REU     SVN    SYR  \
# 0    58.02  ...  6.46  32.07   28.89  103.62  107.09  249.40   85.96  55.20
# 1    37.63  ...  3.04   6.46  103.63   84.78  135.64  115.32   85.20  22.35
# 2    30.46  ...  2.31  10.20   48.47   55.22   73.45  177.42   35.55  33.56
# 3     5.36  ...  0.53  15.54   88.26   26.42  133.90  214.87  152.15  11.86
# 4     6.65  ...  1.59  17.88   46.76    3.61   52.71   59.87   37.82  23.34
# ..     ...  ...   ...    ...     ...     ...     ...     ...     ...    ...
# 835   0.87  ...  0.67  13.98   32.03    0.29   32.71   49.77  111.19   0.43
# 836   1.59  ...  0.54  17.40   98.16   24.15   74.14   64.53  117.23   0.82
# 837  22.59  ...  3.50  13.53  155.18   84.40   31.47   39.41   69.75  22.94
# 838   5.83  ...  1.37  26.65  310.85  152.74  380.79  104.22  231.76  10.08
# 839  61.32  ...  2.51  31.55  134.30   71.01  178.62  124.27  124.09  57.52
#
#        TUN     TUR
# 0    34.08  103.27
# 1    27.17   44.62
# 2    36.09   68.85
# 3    29.81   46.07
# 4    10.05  101.80
# ..     ...     ...
# 835  15.27   21.03
# 836  21.66   20.65
# 837  22.42   29.38
# 838  32.29   37.34
# 839  14.74  106.09
#
# [840 rows x 22 columns]

# %% [markdown]
# I created the below function to be able to calculate the desired average values. I added the "period" variable to be able to use the function on both annual and monthly data.
#
# And I created an if-else block. In this if-else block, annual or monthly data will be processed depending on how the function is called with "period". In this way, monthly or annual data can be calculated without mixing them together. And it groups data acording to desired date type, so we don't get confused.
#
# I used datetime elements when making date-related adjustments.
#
# This function returns a table of the monthly or annual average of the desired value.

# %%
def calculate_averages(data, period):
    df_data = pd.DataFrame(data)
    df_data['Date'] = pd.to_datetime(df_data['Date'], format='%Y-%m')
    
    if period == 'Monthly':
        df_data['Month'] = df_data['Date'].dt.month
        result = df_data.groupby('Month').mean().reset_index()
    elif period == 'Annual':
        df_data['Year'] = df_data['Date'].dt.year
        result = df_data.groupby('Year').mean().reset_index()
    else:
        return None
    
    result = result.drop(columns=['Date'])
    
    return result

# %% [markdown]
# ## Monthly Average Air Surface Temperature

# %%
MAST = calculate_averages(processed_data_temperature, period = 'Monthly' )

MAST
# Out:
#     Month        ALB        BIH        CYP        DZA        EGY        ESP  \
# 0       1   2.721857  -0.582286  10.216429  12.399143  13.345143   5.958143
# 1       2   3.757857   1.023143  10.604429  15.113857  14.869857   6.942714
# 2       3   6.562286   4.740429  12.619714  18.666571  18.283429   9.280286
# 3       4  10.433143   9.220571  16.262143  22.641571  22.962429  11.219286
# 4       5  15.007571  13.796143  20.154714  27.103429  26.636857  14.873000
# 5       6  18.581000  17.248571  24.157571  31.504571  29.191714  19.146857
# 6       7  21.388286  19.311857  26.866714  33.109714  29.837571  22.395000
# 7       8  21.521000  19.245857  27.107857  32.587143  29.795571  22.317714
# 8       9  17.665143  15.290571  24.574000  29.511000  27.881571  19.220714
# 9      10  12.903857  10.393714  20.841714  24.196429  24.494286  14.410714
# 10     11   8.376000   5.356571  15.913429  18.090571  19.144000   9.430000
# 11     12   4.397000   0.741000  11.955000  13.423429  14.812000   6.635429
#
#           GRC        HRV        ISR  ...        LBY        MAR        MCO  \
# 0    4.803429   0.885000  12.241429  ...  12.221714   9.685429   5.862857
# 1    5.864000   2.571857  12.936429  ...  14.395143  11.347571   5.997143
# 2    8.231429   6.425429  15.058143  ...  18.190143  13.793571   8.165714
# 2   64.858333   92.911667  13.887500  ...  1.304167  17.310833   58.534167
# 3   66.325833   61.880833  27.568333  ...  2.152500  23.172500   63.436667
# 4   77.809167   82.370833  23.499167  ...  1.526667  25.585833   72.550000
# ..        ...         ...        ...  ...       ...        ...         ...
# 65  72.743333   81.930000  21.026667  ...  2.290000  21.514167   62.748333
# 66  64.165000   96.786667  18.518333  ...  1.118333  23.389167   79.346667
# 67  66.038333   90.944167  11.009167  ...  2.489167  14.946667   53.524167
# 68  75.761667   94.611667  25.376667  ...  2.050000  33.396667  112.834167
# 69  72.950000  101.130000  23.483333  ...  2.329167  17.608333   95.307500
#
#           MLT         MNE         REU         SVN        SYR        TUN  \
# 0   40.722500  112.725833  135.336667   90.868333  15.086667  16.780000
# 1   38.282500  110.780833  115.220833   99.398333  15.694167  13.130000
# 2   21.989167  159.711667  133.290833  103.516667  16.039167  12.672500
# 3   41.865000   79.185000  123.334167   78.640833  23.260833  19.828333
# 4   46.435000  122.163333  112.034167   95.057500  23.267500  13.490000
# ..        ...         ...         ...         ...        ...        ...
# 65  34.430833  102.709167  142.155000   92.348333  17.922500  15.582500
# 66  32.710000  152.777500  103.489167  117.884167  15.535833  15.634167
# 67  37.402500  121.100833   98.981667  115.371667  14.022500  16.927500
# 68  42.935833  144.320833  153.328333  109.058333  30.192500  17.461667
# 69  45.458333  135.440833   84.646667  118.467500  27.032500  19.375833
#
#           TUR
# 0   50.032500
# 1   62.815833
# 2   53.745000
# 3   61.848333
# 4   63.615833
# ..        ...
# 65  62.190000
# 66  60.818333
# 67  53.742500
# 68  65.833333
# 69  59.724167
#
# [70 rows x 22 columns]

# %% [markdown]
# The below function allows visualizing the data and tables we have obtained. Since I wanted to be able to use this function in all my graphs, I added data_name and period variables. Thanks to the data_name variable, I can use the function for both "temperature" and "precipitation" situations. The period variable makes the function suitable for monthly and yearly situations.
#
# Finally, since the first column is the date column, I don't want to see it on the chart. So I wrote exclude_first_column=True and prevented the date variable from being plotted on the chart.
#
# I also defined the exclude_first_column variable in the If-Else block and made it work properly.
#
# To plot the graph, I started plotting the data I grouped by country, one by one, with a for loop.
#
# I named the x-axis period and the y-axis Average value. To make the graph easier to understand, I wrote what the graph is in the title.
#
# I used the plt.legend(loc='best') command to select the most suitable ranges for the values of the chart.
#
# Finally, I completed the visualization by drawing the graph.

# %%
def visualize_averages(dataframe, data_name, period, exclude_first_column=True):
    if exclude_first_column:
        columns_to_plot = dataframe.columns[1:]
    else:
        columns_to_plot = dataframe.columns

    for country in columns_to_plot:
        plt.plot(dataframe.index, dataframe[country], label=country)

    plt.xlabel(f'{period}')
    plt.ylabel(f'Average {data_name}')
    plt.title(f'{period} Average {data_name}')
    plt.legend(loc='best')

    plt.show()

# %%
visualize_averages(MAST, "Surface Temperature", "Monthly")

# %%
visualize_averages(MAPR, "Precipitation", "Monthly")

# %%
visualize_averages(YAPR, "Precipitation", "Annual")

# %%
visualize_averages(YAST, "Surface Temperature", "Annual")
